# 247  2020-02-04  315.309998  319.640015  313.630005  318.850006  318.095062
# 248  2020-02-05  323.519989  324.760010  318.950012  321.450012  320.688934
# 249  2020-02-06  322.570007  325.220001  320.260010  325.209991  324.440002
# 250  2020-02-07  322.369995  323.399994  318.000000  320.029999  320.029999
#
#        Volume
# 0    20993400
# 1    22283500
# 2    22490200
# 3    21835700
# 4    24626800
# 5    18972800
# 6    26114400
# 7    17249700
# 8    18913200
# 9    21873400
# 10   17070200
# 11   27835400
# 12   28215400
# 13   25886200
# 14   27436200
# 15   19737400
# 16   20810400
# 17   24796400
# 18   23999400
# 19   32011000
# 20   32467600
# 21   31032500
# 22   23579500
# 23   39042900
# 24   26219800
# 25   31646400
# 26   31035200
# 27   51034200
# 28   42407700
# 29   43845300
# 30   49800500
# 31   29848400
# 32   20780400
# 33   23564000
# 34   27862000
# 35   22765700
# 36   23271800
# 37   19114300
# 38   18526600
# 39   25881700
# 40   35768200
# 41   21695300
# ..        ...
# 209  32010600
# 210  22605100
# 211  19689200
# 212  34327600
# 213  33396900
# 214  32046500
# 215  28539600
# 216  29007100
# 217  24592300
# 218  68994500
# 219  24643000
# 220  12119700
# 221  23280300
# 222  36566500
# 223  36028600
# 224  25201400
# 225  33870100
# 226  36580700
# 227  29596800
# 228  27218000
# 229  33019800
# 230  42527100
# 231  35161200
# 232  30383000
# 233  40488600
# 234  30480900
# 235  27207300
# 236  34454100
# 237  27710800
# 238  25458100
# 239  26118000
# 240  36634400
# 241  40485000
# 242  40558500
# 243  54057300
# 244  31685800
# 245  49897100
# 246  43496400
# 247  34154100
# 248  29706700
# 249  26356400
# 250  29357800
#
# [251 rows x 7 columns]

# %%
df.shape
# Out:
# (251, 7)

# %% [markdown]
# # Pandas series

# %%
#creatoing an empty series
import pandas as pd  
x = pd.Series()  
print (x)
# Out:
# Series([], dtype: float64)

# %%
##creating series from arrays
import pandas as pd  
import numpy as np  
info = np.array(['P','a','n','d','a','s'])  
a = pd.Series(info)  
print(a)
# Out:
# 0    P
# 1    a
# 2    n
# 3    d
# 4    a
# 5    s
# dtype: object

# %%
#import the pandas library (series from dictionary)  
import pandas as pd  
import numpy as np  
info = {'x' : 0., 'y' : 1., 'z' : 2.}  
a = pd.Series(info)  
print (a)
# Out:
# x    0.0
# y    1.0
# z    2.0
# dtype: float64

# %%
##creating series usinmg scalar
#import pandas library   
import pandas as pd  
import numpy as np  
x = pd.Series(4, index=[0, 1, 2, 3])  
print (x)
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# dtype: int64

# %%
## Accesing data from series position
import pandas as pd  
x = pd.Series([1,2,3],index = ['a','b','c'])  
#retrieve the first element  
print (x[0])
# Out:
# 1

# %%
# Retrieving Index array and data array of a series object
import numpy as np   
import pandas as pd   
x=pd.Series(data=[2,4,6,8])   
y=pd.Series(data=[11.2,18.6,22.5], index=['a','b','c'])   
print(x.index)   
print(x.values)   
print(y.index)   
print(y.values)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# [2 4 6 8]
# Index(['a', 'b', 'c'], dtype='object')
# [11.2 18.6 22.5]

# %%
##Retrieving Types (dtype) and Size of Type (itemsize)
import numpy as np   
import pandas as pd   
a=pd.Series(data=[1,2,3,4])   
b=pd.Series(data=[4.9,8.2,5.6],   
index=['x','y','z'])   
print(a.dtype)   
print(a.itemsize)    
print(b.dtype)   
print(b.itemsize)
# Out:
# int64
# 8
# float64
# 8
# C:\Users\New life\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Series.itemsize is deprecated and will be removed in a future version
#
# C:\Users\New life\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Series.itemsize is deprecated and will be removed in a future version
#   # Remove the CWD from sys.path while we load stuff.

# %%
##retrieving shape
import numpy as np   
import pandas as pd   
a=pd.Series(data=[1,2,3,4])   
b=pd.Series(data=[4.9,8.2,5.6],index=['x','y','z'])   
print(a.shape)   
print(b.shape)
# Out:
# (4,)
# (3,)

# %%
##Retrieving Dimension, Size and Number of bytes:
import numpy as np   
import pandas as pd   
a=pd.Series(data=[1,2,3,4])   
b=pd.Series(data=[4.9,8.2,5.6],  
index=['x','y','z'])   
print(a.ndim, b.ndim)   
print(a.size, b.size)   
print(a.nbytes, b.nbytes)
# Out:
# 1 1
# 4 3
# 32 24

# %%
##Checking Emptiness and Presence of NaNs
import numpy as np   
import pandas as pd   
a=pd.Series(data=[1,2,3,np.NaN])   
b=pd.Series(data=[4.9,8.2,5.6],index=['x','y','z'])   
c=pd.Series()   
print(a.empty,b.empty,c.empty)   
print(a.hasnans,b.hasnans,c.hasnans)   
print(len(a),len(b))   
print(a.count( ),b.count( ))
# Out:
# False False True
# True False False
# 4 3
# 3 3

# %%
#series.map function
import pandas as pd  
import numpy as np  
a = pd.Series(['Java', 'C', 'C++', np.nan])  
a.map({'Java': 'Core'})
# Out:
# 0    Core
# 1     NaN
# 2     NaN
# 3     NaN
# dtype: object

# %%
import pandas as pd  
import numpy as np  
a = pd.Series(['Java', 'C', 'C++', np.nan])  
a.map({'Java': 'Core'})  
a.map('I like {}'.format, na_action='ignore')
# Out:
# 0    I like Java
# 1       I like C
# 2     I like C++
# 3            NaN
# dtype: object

# %%
## Pandas import pandas as pd  
# calculate standard deviation  
import pandas as pd  
# calculate standard deviation  
import numpy as np   
print(np.std([4,7,2,1,6,3]))  
print(np.std([6,9,15,2,-17,15,4]))
# Out:
# 2.1147629234082532
# 10.077252622027656

# %%
import pandas as pd  
import numpy as np  
   
#Create a DataFrame  
info = {  
    'Name':['Parker','Smith','John','William'],  
   'sub1_Marks':[52,38,42,37],  
   'sub2_Marks':[41,35,29,36]}   
data = pd.DataFrame(info)  
data  
# standard deviation of the dataframe  
data.std()
# Out:
# sub1_Marks    6.849574
# sub2_Marks    4.924429
# dtype: float64

# %%
##Pandas Series.to_frame()(returns the representation of series)
s = pd.Series(["a", "b", "c"],  
name="vals")  
s.to_frame()
# Out:
#   vals
# 0    a
# 1    b
# 2    c

# %%
import pandas as pd   
import matplotlib.pyplot as plt     
emp = ['Parker', 'John', 'Smith', 'William']   
id = [102, 107, 109, 114]     
emp_series = pd.Series(emp)   
id_series = pd.Series(id)     
frame = { 'Emp': emp_series, 'ID': id_series }   
result = pd.DataFrame(frame)     
print(result)
# Out:
#        Emp   ID
# 0   Parker  102
# 1     John  107
# 2    Smith  109
# 3  William  114

# %%
##Pandas Series.unique()
#Returns:
##(This method returns a numpy.ndarray or ExtensionArray object and can be:

##index: Returns when user passes index as an input.
##Categorical: Returns when user passes a Categorical dtype as an input.
#3ndarray: Returns when user passes a ndarray/Series as an input.)
import pandas as pd  
pd.unique(pd.Series([2, 1, 3, 3]))  
pd.unique(pd.Series([pd.Timestamp('20160101'),  
pd.Timestamp('20160101')]))
# Out:
# array(['2016-01-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
import pandas as pd  
import numpy as np  
pd.unique(pd.Index([pd.Timestamp('20160101', tz='US/Eastern'),  
pd.Timestamp('20160101', tz='US/Eastern')]))
# Out:
# DatetimeIndex(['2016-01-01 00:00:00-05:00'], dtype='datetime64[ns, US/Eastern]', freq=None)

# %%
##Pandas Series.value_counts()
##returns the counted series
import pandas as pd  
import numpy as np  
index = pd.Index([2, 1, 1, np.nan, 3])  
index.value_counts()
# Out:
# 1.0    2
# 3.0    1
# 2.0    1
# dtype: int64

# %%
import pandas as pd  
import numpy as np  
index = pd.Index([2, 1, 1, np.nan, 3])  
a = pd.Series([2, 1, 1, np.nan, 3])  
a.value_counts(normalize=True)
# Out:
# 1.0    0.50
# 3.0    0.25
# 2.0    0.25
# dtype: float64

# %%
import pandas as pd  
index = pd.Index([1, 3, 2, 2, 1, np.nan])  
index.value_counts()  
a = pd.Series([1, 3, 2, 2, 1, np.nan])  
a.value_counts(bins=2)
# Out:
# (0.997, 2.0]    4
# (2.0, 3.0]      1
# dtype: int64

# %%
import pandas as pd  
index = pd.Index([1, 3, 2, 2, 1, np.nan])  
index.value_counts()  
a = pd.Series([1, 3, 2, 2, 1, np.nan])  
a.value_counts(dropna=False)
# Out:
# 2.0    2
# 1.0    2
# NaN    1
# 3.0    1
# dtype: int64

# %% [markdown]
# # Pandas dataframe

# %%
##creating empty datasfame
# importing the pandas library  
import pandas as pd  
df = pd.DataFrame()  
print (df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#using list
# importing the pandas library  
import pandas as pd  
# a list of strings  
x = ['Python', 'Pandas']  
  
# Calling DataFrame constructor on list  
df = pd.DataFrame(x)  
print(df)
# Out:
#         0
# 0  Python
# 1  Pandas

# %%
#Create a DataFrame from Dict of ndarrays/ Lists
# importing the pandas library  
import pandas as pd  
info = {'ID' :[101, 102, 103],'Department' :['B.Sc','B.Tech','M.Tech',]}  
df = pd.DataFrame(info)  
print (df)
# Out:
#     ID Department
# 0  101       B.Sc
# 1  102     B.Tech
# 2  103     M.Tech

# %%
#create dataframer of dict of series
# importing the pandas library  
import pandas as pd  
  
info = {'one' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f']),  
   'two' : pd.Series([1, 2, 3, 4, 5, 6, 7, 8], index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])}  
  
d1 = pd.DataFrame(info)  
print (d1)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  4.0    4
# e  5.0    5
# f  6.0    6
# g  NaN    7
# h  NaN    8

# %%
#column selection
# importing the pandas library  
import pandas as pd  
  
info = {'one' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f']),  
   'two' : pd.Series([1, 2, 3, 4, 5, 6, 7, 8], index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])}  
  
d1 = pd.DataFrame(info)  
print (d1 ['one'])
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# f    6.0
# g    NaN
# h    NaN
# Name: one, dtype: float64

# %%
##column addition
# importing the pandas library  
import pandas as pd  
  
info = {'one' : pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e']),  
   'two' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])}  
  
df = pd.DataFrame(info)  
  
# Add a new column to an existing DataFrame object   
  
print ("Add new column by passing series")  
df['three']=pd.Series([20,40,60],index=['a','b','c'])  
print (df)  
  
print ("Add new column using existing DataFrame columns")  
df['four']=df['one']+df['three']  
  
print (df)
# Out:
# Add new column by passing series
#    one  two  three
# a  1.0    1   20.0
# b  2.0    2   40.0
# c  3.0    3   60.0
# d  4.0    4    NaN
# e  5.0    5    NaN
# f  NaN    6    NaN
# Add new column using existing DataFrame columns
#    one  two  three  four
# a  1.0    1   20.0  21.0
# b  2.0    2   40.0  42.0
# c  3.0    3   60.0  63.0
# d  4.0    4    NaN   NaN
# e  5.0    5    NaN   NaN
# f  NaN    6    NaN   NaN

# %%
##column deletion
# importing the pandas library  
import pandas as pd  
  
info = {'one' : pd.Series([1, 2], index= ['a', 'b']),   
   'two' : pd.Series([1, 2, 3], index=['a', 'b', 'c'])}  
     
df = pd.DataFrame(info)  
print ("The DataFrame:")  
print (df)  
  
# using del function  
print ("Delete the first column:")  
del df['one']  
print (df)  
# using pop function  
print ("Delete the another column:")  
df.pop('two')  
print (df)
# Out:
# The DataFrame:
#    one  two
# a  1.0    1
# b  2.0    2
# c  NaN    3
# Delete the first column:
#    two
# a    1
# b    2
# c    3
# Delete the another column:
# Empty DataFrame
# Columns: []
# Index: [a, b, c]

# %%
##row serlection
# importing the pandas library  
import pandas as pd  
  
info = {'one' : pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e']),   
   'two' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])}  
  
df = pd.DataFrame(info)  
print (df.loc['b'])
# Out:
# one    2.0
# two    2.0
# Name: b, dtype: float64

# %%
#selection by integer location
# importing the pandas library  
import pandas as pd  
info = {'one' : pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e']),  
   'two' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])}  
df = pd.DataFrame(info)  
print (df.iloc[3])
# Out:
# one    4.0
# two    4.0
# Name: d, dtype: float64

# %%
##Slice Rows

#3It is another method to select multiple rows using ':' operator.
import pandas as pd  
info = {'one' : pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e']),   
   'two' : pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])}  
df = pd.DataFrame(info)  
print (df[2:5])
# Out:
#    one  two
# c  3.0    3
# d  4.0    4
# e  5.0    5

# %%
##addition of rows
import pandas as pd  
d = pd.DataFrame([[7, 8], [9, 10]], columns = ['x','y'])  
d2 = pd.DataFrame([[11, 12], [13, 14]], columns = ['x','y'])  
d = d.append(d2)  
print (d)
# Out:
#     x   y
# 0   7   8
# 1   9  10
# 0  11  12
# 1  13  14

# %%
##deletion of rows
# importing the pandas library  
import pandas as pd  
  
a_info = pd.DataFrame([[4, 5], [6, 7]], columns = ['x','y'])  
b_info = pd.DataFrame([[8, 9], [10, 11]], columns = ['x','y'])  
  
a_info = a_info.append(b_info)  
  
# Drop rows with label 0  
a_info = a_info.drop(0)

# %% [markdown]
# # Pandas operation

# %%
import pandas as pd  
aa = pd.read_csv("AAPL.csv")  
aa.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-02-11  171.050003  171.210007  169.250000  169.429993  167.240967
# 1  2019-02-12  170.100006  171.000000  169.699997  170.889999  168.682114
# 2  2019-02-13  171.389999  172.479996  169.919998  170.179993  167.981277
# 3  2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 4  2019-02-15  171.250000  171.699997  169.750000  170.419998  168.218201
#
#      Volume
# 0  20993400
# 1  22283500
# 2  22490200
# 3  21835700
# 4  24626800

# %%
#adding new column
import pandas as pd  
aa = pd.read_csv("AAPL.csv")  
aa["Profit"] = "24"  
aa.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-02-11  171.050003  171.210007  169.250000  169.429993  167.240967
# 1  2019-02-12  170.100006  171.000000  169.699997  170.889999  168.682114
# 2  2019-02-13  171.389999  172.479996  169.919998  170.179993  167.981277
# 3  2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 4  2019-02-15  171.250000  171.699997  169.750000  170.419998  168.218201
#
#      Volume Profit
# 0  20993400     24
# 1  22283500     24
# 2  22490200     24
# 3  21835700     24
# 4  24626800     24

# %%
##adding new column department
import pandas as pd  
aa = pd.read_csv("AAPL.csv")  
aa.insert(2, column = "Department", value = "company")  
aa.head()
# Out:
#          Date        Open Department        High         Low       Close  \
# 0  2019-02-11  171.050003    company  171.210007  169.250000  169.429993
# 1  2019-02-12  170.100006    company  171.000000  169.699997  170.889999
# 2  2019-02-13  171.389999    company  172.479996  169.919998  170.179993
# 3  2019-02-14  169.710007    company  171.259995  169.380005  170.800003
# 4  2019-02-15  171.250000    company  171.699997  169.750000  170.419998
#
#     Adj Close    Volume
# 0  167.240967  20993400
# 1  168.682114  22283500
# 2  167.981277  22490200
# 3  168.593292  21835700
# 4  168.218201  24626800

# %%
##dataframe to numpy array
import pandas as pd  
pd.DataFrame({"P": [2, 3], "Q": [4, 5]}).to_numpy()  
info = pd.DataFrame({"P": [2, 3], "Q": [4.0, 5.8]})  
info.to_numpy()  
info['R'] = pd.date_range('2000', periods=2)  
info.to_numpy()
# Out:
# array([[2, 4.0, Timestamp('2000-01-01 00:00:00')],
#        [3, 5.8, Timestamp('2000-01-02 00:00:00')]], dtype=object)

# %%
import pandas as pd  
#initializing the dataframe  
info = pd.DataFrame([[17, 62, 35],[25, 36, 54],[42, 20, 15],[48, 62, 76]],  
columns=['x', 'y', 'z'])  
print('DataFrame\n----------\n', info)  
#convert the dataframe to a numpy array  
arr = info.to_numpy()  
print('\nNumpy Array\n----------\n', arr)
# Out:
# DataFrame
# ----------
#      x   y   z
# 0  17  62  35
# 1  25  36  54
# 2  42  20  15
# 3  48  62  76
#
# Numpy Array
# ----------
#  [[17 62 35]
#  [25 36 54]
#  [42 20 15]
#  [48 62 76]]

# %%
##dataframe to csv
import pandas as pd  
# 227  2020-01-06  293.790009  299.959991  292.750000  299.799988  299.090149
# 228  2020-01-07  299.839996  300.899994  297.480011  298.390015  297.683533
# 229  2020-01-08  297.160004  304.440002  297.160004  303.190002  302.472137
# 230  2020-01-09  307.239990  310.429993  306.200012  309.630005  308.896912
# 231  2020-01-10  310.600006  312.670013  308.250000  310.329987  309.595215
# 232  2020-01-13  311.640015  317.070007  311.149994  316.959991  316.209534
# 233  2020-01-14  316.700012  317.570007  312.170013  312.679993  311.939667
# 234  2020-01-15  311.850006  315.500000  309.549988  311.339996  310.602844
# 235  2020-01-16  313.589996  315.700012  312.089996  315.239990  314.493591
# 236  2020-01-17  316.269989  318.739990  315.000000  318.730011  317.975372
# 237  2020-01-21  317.190002  319.019989  316.000000  316.570007  315.820465
# 238  2020-01-22  318.579987  319.989990  317.309998  317.700012  316.947815
# 239  2020-01-23  317.920013  319.559998  315.649994  319.230011  318.474182
# 240  2020-01-24  320.250000  323.329987  317.519989  318.309998  317.556335
# 241  2020-01-27  310.059998  311.769989  304.880005  308.950012  308.218506
# 242  2020-01-28  312.600006  318.399994  312.190002  317.690002  316.937805
# 243  2020-01-29  324.450012  327.850006  321.380005  324.339996  323.572052
# 244  2020-01-30  320.540009  324.089996  318.750000  323.869995  323.103180
# 245  2020-01-31  320.929993  322.679993  308.290009  309.510010  308.777191
# 246  2020-02-03  304.299988  313.489990  302.220001  308.660004  307.929199
# 247  2020-02-04  315.309998  319.640015  313.630005  318.850006  318.095062
# 248  2020-02-05  323.519989  324.760010  318.950012  321.450012  320.688934
# 249  2020-02-06  322.570007  325.220001  320.260010  325.209991  324.440002
# 250  2020-02-07  322.369995  323.399994  318.000000  320.029999  320.029999
#
#        Volume
# 0    20993400
# 1    22283500
# 2    22490200
# 3    21835700
# 4    24626800
# 5    18972800
# 6    26114400
# 7    17249700
# 8    18913200
# 9    21873400
# 10   17070200
# 11   27835400
# 12   28215400
# 13   25886200
# 14   27436200
# 15   19737400
# 16   20810400
# 17   24796400
# 18   23999400
# 19   32011000
# 20   32467600
# 21   31032500
# 22   23579500
# 23   39042900
# 24   26219800
# 25   31646400
# 26   31035200
# 27   51034200
# 28   42407700
# 29   43845300
# ..        ...
# 221  23280300
# 222  36566500
# 223  36028600
# 224  25201400
# 225  33870100
# 226  36580700
# 227  29596800
# 228  27218000
# 229  33019800
# 230  42527100
# 231  35161200
# 232  30383000
# 233  40488600
# 234  30480900
# 235  27207300
# 236  34454100
# 237  27710800
# 238  25458100
# 239  26118000
# 240  36634400
# 241  40485000
# 242  40558500
# 243  54057300
# 244  31685800
# 245  49897100
# 246  43496400
# 247  34154100
# 248  29706700
# 249  26356400
# 250  29357800
#
# [251 rows x 7 columns]

# %% [markdown]
# # Pandas data operation

# %%
##data processing with multiple index
import pandas as pd  
info = pd.Series([11, 14, 17, 24, 19, 32, 34, 27],  
index = [['x', 'x', 'x', 'x', 'y', 'y', 'y', 'y'],  
['obj1', 'obj2', 'obj3', 'obj4', 'obj1', 'obj2', 'obj3', 'obj4']])  
data
# Out:
# {'Name': ['Smith', 'Parker'],
#  'ID': [101, NaT],
#  'Language': [NaT, 'JavaScript']}

# %%
import pandas as pd  
aa = pd.read_csv("AAPL.csv")  
aa.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-02-11  171.050003  171.210007  169.250000  169.429993  167.240967
# 1  2019-02-12  170.100006  171.000000  169.699997  170.889999  168.682114
# 2  2019-02-13  171.389999  172.479996  169.919998  170.179993  167.981277
# 3  2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 4  2019-02-15  171.250000  171.699997  169.750000  170.419998  168.218201
#
#      Volume
# 0  20993400
# 1  22283500
# 2  22490200
# 3  21835700
# 4  24626800

# %%
# importing pandas module   
import pandas as pd    
# making data frame from csv file   
info = pd.read_csv("AAPL.csv")     
# making a copy of old data frame   
copy = pd.read_csv("AAPL.csv")   
    
# creating value with all null values in new data frame   
copy["Null Column"]= None  
    
# checking if column is inserted properly    
print(info.columns.values, "\n", copy.columns.values)   
    
# comparing values before dropping null column   
print("\nColumn number before dropping Null column\n",   
       len(info.dtypes), len(copy.dtypes))   
    
# dropping column with all null values   
copy.dropna(axis = 1, how ='all', inplace = True)   
    
# comparing values after dropping null column   
print("\nColumn number after dropping Null column\n",   
      len(info.dtypes), len(info.dtypes))
# Out:
# ['Date' 'Open' 'High' 'Low' 'Close' 'Adj Close' 'Volume']
#  ['Date' 'Open' 'High' 'Low' 'Close' 'Adj Close' 'Volume' 'Null Column']
#
# Column number before dropping Null column
#  7 8
#
# Column number after dropping Null column
#  7 7

# %%
#fllna 
import pandas as pd  
# Create a dataframe  
info = pd.DataFrame(data={'x':[10,20,30,40,50,None]})  
print(info)  
# Fill null value to dataframe using 'inplace'  
info.fillna(value=0, inplace=True)  
print(info)
# Out:
#       x
# 0  10.0
# 1  20.0
# 2  30.0
# 3  40.0
# 4  50.0
# 5   NaN
#       x
# 0  10.0
# 1  20.0
# 2  30.0
# 3  40.0
# 4  50.0
# 5   0.0

# %%
import pandas as pd  
# Create a dataframe  
info = pd.DataFrame([[np.nan,np.nan, 20, 0],  
[1, np.nan, 4, 1],  
[np.nan, np.nan, np.nan, 5],  
[np.nan, 20, np.nan, 2]],  
columns=list('ABCD'))  
info
# Out:
#      A     B     C  D
# 0  NaN   NaN  20.0  0
# 1  1.0   NaN   4.0  1
# 2  NaN   NaN   NaN  5
# 3  NaN  20.0   NaN  2

# %%
#3daataframe replace
import pandas as pd  
info = pd.DataFrame({'Language known': ['Python', 'Android', 'C', 'Android', 'Python', 'C++', 'C']},  
index=['Parker', 'Smith', 'John', 'William', 'Dean', 'Christina', 'Cornelia'])  
print(info)   
dictionary = {"Python": 1, "Android": 2, "C": 3, "Android": 4, "C++": 5}  
info1 = info.replace({"Language known": dictionary})  
print("\n\n")  
print(info1)
# Out:
#           Language known
# Parker            Python
# Smith            Android
# John                   C
# William          Android
# Dean              Python
# Christina            C++
# Cornelia               C
#
#
#
#            Language known
# Parker                  1
# Smith                   4
# John                    3
# William                 4
# Dean                    1
# Christina               5
# Cornelia                3

# %%
import pandas as pd  
info = pd.DataFrame({  
    'name':['Parker','Smith','John'],  
    'age':[27,34,31],  
    'city':['US','Belgium','London']  
})  
info.replace([29],38)
# Out:
#      name  age     city
# 0  Parker   27       US
# 1   Smith   34  Belgium
# 2    John   31   London
